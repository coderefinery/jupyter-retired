# %%
import numpy as np

# %% [markdown]
# ### %timeit

# %%
# %timeit np.linalg.eigvals(np.random.rand(100,100))
# Out:
# The slowest run took 7.05 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100 loops, best of 3: 4.79 ms per loop

# %%
# %%timeit 
a = np.random.rand(100, 100)
np.linalg.eigvals(a)
# Out:
# 100 loops, best of 3: 5.03 ms per loop

# %% [markdown]
# ### %capture

# %%
# %%capture?

# %%
# %%capture output
# %ls

# %%
output.stdout, output.stderr
# Out:
# (u'00_introduction.html         bar.html\r\n00_introduction.pdf          contour_demo.py\r\n00_introduction.slides.html  \x1bexample_notebooks\x1b[m\x1b[m/\r\n00_slides.ipynb              foo.py\r\n01_firststeps                \x1bimg\x1b[m\x1b[m/\r\n01_firststeps.ipynb          mynotes.mkd\r\n04_cython.ipynb              mynotes.mkd~\r\n\x1bGW\x1b[m\x1b[m/                          notes.mkd\r\nNN_fortran_cython.ipynb      notes.mkd~\r\nNN_magics.ipynb              prun0\r\nNN_matplotlib.ipynb          prun1\r\nNN_parallel.ipynb            py3.list\r\nNN_profiling.ipynb           py35.list\r\nNN_widgets.ipynb             solutions.ipynb\r\nREADME.md                    \x1btest\x1b[m\x1b[m/\r\nUntitled.ipynb               \x1btestdirectory\x1b[m\x1b[m/\r\nUntitled1.ipynb              testing.ipynb\r\nUntitled2.ipynb              untitled.py\r\nUntitled3.ipynb              untitled.txt\r\nUntitled4.ipynb              untitled1.txt\r\n',
#  '')

# %%
output.show()
# Out:
# 00_introduction.html         bar.html
# 00_introduction.pdf          contour_demo.py
# 00_introduction.slides.html  example_notebooks/
# 00_slides.ipynb              foo.py
# 01_firststeps                img/
# 01_firststeps.ipynb          mynotes.mkd
# 04_cython.ipynb              mynotes.mkd~
# GW/                          notes.mkd
# NN_fortran_cython.ipynb      notes.mkd~
# NN_magics.ipynb              prun0
# NN_matplotlib.ipynb          prun1
# NN_parallel.ipynb            py3.list
# NN_profiling.ipynb           py35.list
# NN_widgets.ipynb             solutions.ipynb
# README.md                    test/
# Untitled.ipynb               testdirectory/
# Untitled1.ipynb              testing.ipynb
# Untitled2.ipynb              untitled.py
# Untitled3.ipynb              untitled.txt
# Untitled4.ipynb              untitled1.txt

# %% [markdown]
# ### %writefile

# %%
# %%writefile foo.py
print('Hello world')
# Out:
# Overwriting foo.py

# %% [markdown]
# ### %run

# %%
# %run foo
# Out:
# Hello world

# %% [markdown]
# ### %env

# %%
# %env OMP_NUM_THREADS=4
# Out:
# env: OMP_NUM_THREADS=4

# %% [markdown]
# ### %store

# %%
data = 'string to pass to a different notebook'
# %store data
del data # This has deleted the variable

# %% [markdown]
# ### Shell commands

# %%
# !echo "hello"
# Out:
# hello

# %%
# %sx?

# %%
ls_out = %sx ls
ls_out?

# %%
ls_out2 = !ls # same thing as above

# %%
# !pip list
# Out:
# DEPRECATION: The default format will switch to columns in the future. You can use --format=(legacy|columns) (or define a format=(legacy|columns) in your pip.conf under the [list] section) to disable this warning.
# alabaster (0.7.8)
# aldjemy (0.6.0)
# amqp (1.4.9)
# anaconda-client (1.4.0)
# anaconda-navigator (1.2.1)
# anyjson (0.3.3)
# appnope (0.1.0)
# appscript (1.0.1)
# argcomplete (1.0.0)
# astropy (1.2.1)
# Babel (2.3.3)
# backports-abc (0.4)
# backports.shutil-get-terminal-size (1.0.0)
# backports.ssl-match-hostname (3.4.0.2)
# beautifulsoup4 (4.4.1)
# billiard (3.3.0.19)
# bitarray (0.8.1)
# blaze (0.10.1)
# bokeh (0.12.0)
# boto (2.40.0)
# Bottleneck (1.1.0)
# cdecimal (2.3)
# celery (3.1.17)
# cffi (1.8.2)
# chest (0.2.3)
# click (6.6)
# cloudpickle (0.2.1)
# clyent (1.2.2)
# colorama (0.3.7)
# conda (4.2.13)
# conda-build (1.21.3)
# configobj (5.0.6)
# configparser (3.5.0b2)
# contextlib2 (0.5.3)
# cryptography (1.5)
# cycler (0.10.0)
# Cython (0.24)
# cytoolz (0.8.0)
# dask (0.10.0)
# datashape (0.5.2)
# decorator (4.0.10)
# dill (0.2.5)
# Django (1.7.4)
# django-celery (3.1.16)
# django-extensions (1.5.0)
# django-tastypie (0.12.1)
# docutils (0.12)
# dynd (0.7.3.dev1)
# ecdsa (0.13)
# enum34 (1.1.6)
# et-xmlfile (1.0.1)
# ete3 (3.0.0b35)
# fastcache (1.0.2)
# Flask (0.11.1)
# Flask-Cors (2.1.2)
# fortran-magic (0.7)
# frozendict (1.0)
# funcsigs (1.0.2)
# functools32 (3.2.3.post2)
# futures (3.0.5)
# gevent (1.1.1)
# greenlet (0.4.10)
# grin (1.2.1)
# h5py (2.6.0)
# HeapDict (1.0.0)
# idna (2.1)
# imagesize (0.7.1)
# ipaddress (1.0.16)
# ipykernel (4.3.1)
# ipyparallel (5.2.0)
# ipython (5.1.0)
# ipython-genutils (0.1.0)
# ipywidgets (4.1.1)
# itsdangerous (0.24)
# jdcal (1.2)
# jedi (0.9.0)
# Jinja2 (2.8)
# jsonschema (2.5.1)
# julia (0.1.1)
# jupyter (1.0.0)
# jupyter-client (4.3.0)
# jupyter-console (4.1.1)
# jupyter-core (4.1.0)
# kombu (3.0.35)
# llvmlite (0.14.0)
# locket (0.2.0)
# lxml (3.6.0)
# MarkupSafe (0.23)
# matplotlib (1.5.1)
# meld3 (1.0.0)
# mistune (0.7.2)
# mpmath (0.19)
# multipledispatch (0.4.8)
# nb-anacondacloud (1.2.0)
# nb-conda (2.0.0)
# nb-conda-kernels (2.0.0)
# nbconvert (4.2.0)
# nbformat (4.0.1)
# nbpresent (3.0.2)
# networkx (1.11)
# nltk (3.2.1)
# nose (1.3.7)
# notebook (4.2.1)
# numba (0.29.0+0.gead0dd3.dirty)
# numexpr (2.6.0)
# numpy (1.11.2)
# odo (0.5.0)
# openpyxl (2.3.2)
# pandas (0.18.1)
# paramiko (2.0.2)
# partd (0.3.4)
# passlib (1.6.5)
# path.py (0.0.0)
# pathlib2 (2.1.0)
# patsy (0.4.1)
# pep8 (1.7.0)
# pexpect (4.2.1)
# pickleshare (0.7.4)
# Pillow (3.2.0)
# pip (9.0.1)
# plum (0.4.3)
# ply (3.8)
# prompt-toolkit (1.0.9)
# psutil (4.3.0)
# ptyprocess (0.5.1)
# py (1.4.31)
# pyasn1 (0.1.9)
# PyAudio (0.2.7)
# pycosat (0.6.1)
# pycparser (2.14)
# pycrypto (2.6.1)
# pycurl (7.43.0)
# pyflakes (1.2.3)
# Pygments (2.1.3)
# pyOpenSSL (16.0.0)
# pyparsing (2.1.4)
# pytest (2.9.2)
# python-dateutil (2.4.0)
# python-gssapi (0.6.4)
# python-mimeparse (0.1.4)
# pytz (2014.10)
# PyYAML (3.11)
# pyzmq (15.2.0)
# qtconsole (4.2.1)
# QtPy (1.0.2)
# redis (2.10.5)
# requests (2.10.0)
# rise (4.0.0b1)
# rope (0.9.4)
# rpy2 (2.8.4)
# ruamel-yaml (-VERSION)
# scikit-image (0.12.3)
# scikit-learn (0.17.1)
# scipy (0.17.1)
# seaborn (0.7.1)
# setuptools (28.8.0)
# simplegeneric (0.8.1)
# singledispatch (3.4.0.3)
# six (1.10.0)
# snowballstemmer (1.2.1)
# sockjs-tornado (1.0.3)
# Sphinx (1.4.1)
# sphinx-rtd-theme (0.1.9)
# spyder (2.3.9)
# SQLAlchemy (1.0.12)
# SQLAlchemy-Utils (0.31.2)
# statsmodels (0.6.1)
# supervisor (3.1.3)
# sympy (1.0)
# tables (3.2.2)
# tabulate (0.7.5)
# terminado (0.6)
# toolz (0.8.0)
# tornado (4.3)
# traitlets (4.3.1)
# ultrajson (1.35)
# unicodecsv (0.14.1)
# validate-email (1.3)
# virtualenv (15.0.3)
# voluptuous (0.8.11)
# wcwidth (0.1.7)
# Werkzeug (0.11.10)
# wheel (0.29.0)
# xlrd (1.0.0)
# XlsxWriter (0.9.2)
# xlwings (0.7.2)
# xlwt (1.1.2)
